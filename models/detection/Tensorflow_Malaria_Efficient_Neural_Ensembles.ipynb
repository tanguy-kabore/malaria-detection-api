# %% [markdown]
# **Étape 1: Importation des bibliothèques**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import LearningRateScheduler, Callback
import tensorflow_datasets as tfds

# %% [markdown]
# **Étape 2: Chargement et préparation du dataset Malaria**
#
# On utilise le dataset Malaria de TensorFlow Datasets. Il contient des images de cellules infectées et non infectées, que l’on prétraite (redimensionnement et normalisation).

# %%
# Charger le dataset Malaria
(ds_train, ds_test), ds_info = tfds.load('malaria',
                                         split=['train[:80%]', 'train[80%:]'],
                                         shuffle_files=True,
                                         as_supervised=True,
                                         with_info=True)

# Redimensionner les images et les normaliser
IMG_SIZE = 224
BATCH_SIZE = 32

def preprocess_image(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = image / 255.0  # Normalisation
    return image, label

# Appliquer le prétraitement
ds_train = ds_train.map(preprocess_image).batch(BATCH_SIZE).prefetch(tf.data.experimental.AUTOTUNE)
ds_test = ds_test.map(preprocess_image).batch(BATCH_SIZE).prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to C:\Users\HP\tensorflow_datasets\malaria\1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
# ---------------------------------------------------------------------------
# DownloadError                             Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Charger le dataset Malaria
# ----> 2 (ds_train, ds_test), ds_info = tfds.load('malaria',
#       3                                          split=['train[:80%]', 'train[80%:]'],
#       4                                          shuffle_files=True,
#       5                                          as_supervised=True,
#       6                                          with_info=True)
#       8 # Redimensionner les images et les normaliser
#       9 IMG_SIZE = 224
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\logging\__init__.py:169, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     167 metadata = self._start_call()
#     168 try:
# --> 169   return function(*args, **kwargs)
#     170 except Exception:
#     171   metadata.mark_error()
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\load.py:647, in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     528 """Loads the named dataset into a `tf.data.Dataset`.
#     529
#     530 `tfds.load` is a convenience method that:
#    (...)
#     639     Split-specific information is available in `ds_info.splits`.
#     640 """  # fmt: skip
#     641 dbuilder = _fetch_builder(
#     642     name,
#     643     data_dir,
#     644     builder_kwargs,
#     645     try_gcs,
#     646 )
# --> 647 _download_and_prepare_builder(dbuilder, download, download_and_prepare_kwargs)
#     649 if as_dataset_kwargs is None:
#     650   as_dataset_kwargs = {}
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\load.py:506, in _download_and_prepare_builder(dbuilder, download, download_and_prepare_kwargs)
#     504 if download:
#     505   download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 506   dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\logging\__init__.py:169, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     167 metadata = self._start_call()
#     168 try:
# --> 169   return function(*args, **kwargs)
#     170 except Exception:
#     171   metadata.mark_error()
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\dataset_builder.py:699, in DatasetBuilder.download_and_prepare(self, download_dir, download_config, file_format)
#     697   self.info.read_from_directory(self.data_dir)
#     698 else:
# --> 699   self._download_and_prepare(
#     700       dl_manager=dl_manager,
#     701       download_config=download_config,
#     702   )
#     704   # NOTE: If modifying the lines below to put additional information in
#     705   # DatasetInfo, you'll likely also want to update
#     706   # DatasetInfo.read_from_directory to possibly restore these attributes
#     707   # when reading from package data.
#     708   self.info.download_size = dl_manager.downloaded_size
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\dataset_builder.py:1669, in GeneratorBasedBuilder._download_and_prepare(self, dl_manager, download_config)
#    1666 if download_config.max_examples_per_split == 0:
#    1667   return
# -> 1669 split_infos = self._generate_splits(dl_manager, download_config)
#    1671 # Update the info object with the splits.
#    1672 split_dict = splits_lib.SplitDict(split_infos)
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\dataset_builder.py:1620, in GeneratorBasedBuilder._generate_splits(self, dl_manager, download_config)
#    1618 else:
#    1619   optional_pipeline_kwargs = {}
# -> 1620 split_generators = self._split_generators(  # pylint: disable=unexpected-keyword-arg
#    1621     dl_manager, **optional_pipeline_kwargs
#    1622 )
#    1623 # TODO(tfds): Could be removed once all datasets are migrated.
#    1624 # https://github.com/tensorflow/datasets/issues/2537
#    1625 # Legacy mode (eventually convert list[SplitGeneratorLegacy] -> dict)
#    1626 split_generators = split_builder.normalize_legacy_split_generators(
#    1627     split_generators=split_generators,
#    1628     generator_fn=self._generate_examples,
#    1629     is_beam=isinstance(self, BeamBasedBuilder),
#    1630 )
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\datasets\malaria\malaria_dataset_builder.py:55, in Builder._split_generators(self, dl_manager)
#      52 def _split_generators(self, dl_manager):
#      53   """Define Splits."""
# ---> 55   path = dl_manager.download_and_extract(_URL)
#      57   return [
#      58       tfds.core.SplitGenerator(
#      59           name=tfds.Split.TRAIN,
#    (...)
#      63       ),
#      64   ]
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\download\download_manager.py:694, in DownloadManager.download_and_extract(self, url_or_urls)
#     692 with self._downloader.tqdm():
#     693   with self._extractor.tqdm():
# --> 694     return _map_promise(self._download_extract, url_or_urls)
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\download\download_manager.py:791, in _map_promise(map_fn, all_inputs)
#     789 """Map the function into each element and resolve the promise."""
#     790 all_promises = tree.map_structure(map_fn, all_inputs)  # Apply the function
# --> 791 res = tree.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     792 return res
#
# File c:\Python312\Lib\site-packages\tree\__init__.py:428, in map_structure(func, *structures, **kwargs)
#     425 for other in structures[1:]:
#     426   assert_same_structure(structures[0], other, check_types=check_types)
#     427 return unflatten_as(structures[0],
# --> 428                     [func(*args) for args in zip(*map(flatten, structures))])
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\download\download_manager.py:791, in _map_promise.<locals>.<lambda>(p)
#     789 """Map the function into each element and resolve the promise."""
#     790 all_promises = tree.map_structure(map_fn, all_inputs)  # Apply the function
# --> 791 res = tree.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     792 return res
#
# File c:\Python312\Lib\site-packages\promise\promise.py:512, in Promise.get(self, timeout)
#     510 target = self._target()
#     511 self._wait(timeout or DEFAULT_TIMEOUT)
# --> 512 return self._target_settled_value(_raise=True)
#
# File c:\Python312\Lib\site-packages\promise\promise.py:516, in Promise._target_settled_value(self, _raise)
#     514 def _target_settled_value(self, _raise=False):
#     515     # type: (bool) -> Any
# --> 516     return self._target()._settled_value(_raise)
#
# File c:\Python312\Lib\site-packages\promise\promise.py:226, in Promise._settled_value(self, _raise)
#     224 if _raise:
#     225     raise_val = self._fulfillment_handler0
# --> 226     reraise(type(raise_val), raise_val, self._traceback)
#     227 return self._fulfillment_handler0
#
# File ~\AppData\Roaming\Python\Python312\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File c:\Python312\Lib\site-packages\promise\promise.py:844, in _process_future_result.<locals>.handle_future_result(future)
#     841 def handle_future_result(future):
#     842     # type: (Any) -> None
#     843     try:
# --> 844         resolve(future.result())
#     845     except Exception as e:
#     846         tb = exc_info()[2]
#
# File c:\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\download\downloader.py:296, in _Downloader._sync_download(self, url, destination_path, verify)
#     293 except tf.errors.UnimplementedError:
#     294   pass
# --> 296 with _open_url(url, verify=verify) as (response, iter_content):
#     297   fname = _get_filename(response)
#     298   path = os.path.join(destination_path, fname)
#
# File c:\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\download\downloader.py:369, in _open_with_requests(url, **kwargs)
#     367   url = _normalize_drive_url(url)
#     368 with session.get(url, stream=True, **kwargs) as response:
# --> 369   _assert_status(response)
#     370   yield (response, response.iter_content(chunk_size=io.DEFAULT_BUFFER_SIZE))
#
# File c:\Python312\Lib\site-packages\tensorflow_datasets\core\download\downloader.py:396, in _assert_status(response)
#     394 """Ensure the URL response is 200."""
#     395 if response.status_code != 200:
# --> 396   raise download_utils_lib.DownloadError(
#     397       'Failed to get url {}. HTTP code: {}.'.format(
#     398           response.url, response.status_code
#     399       )
#     400   )
#
# DownloadError: Failed to get url https://data.lhncbc.nlm.nih.gov/public/Malaria/cell_images.zip. HTTP code: 403.

# %% [markdown]
# **Étape 3: Création du modèle EfficientNet-B0**
#
# EfficientNet-B0 est utilisé avec des poids pré-entraînés d’ImageNet. On ajoute des couches pour la classification binaire (infecté/non infecté).

# %%
def create_model():
    base_model = EfficientNetB0(include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3), weights='imagenet')
    base_model.trainable = True  # Fine-tuning

    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(128, activation='relu'),
        layers.Dense(1, activation='sigmoid')  # Classification binaire
    ])

    return model

# %% [markdown]
# **Étape 4: Scheduler pour Cosine Annealing**
#
# On utilise le Cosine Annealing pour moduler dynamiquement le taux d'apprentissage.

# %%
def cosine_annealing(epoch):
    initial_lr = 0.001
    epochs = 50
    lr_min = 1e-6
    return lr_min + (initial_lr - lr_min) * (1 + np.cos(np.pi * epoch / epochs)) / 2

# %% [markdown]
# **Étape 5: Callback pour enregistrer les Snapshots**
#
# Le modèle est sauvegardé à la fin des époques 10, 20, 30, 40 et 50.

# %%
class SnapshotCallback(Callback):
    def __init__(self, snapshots):
        super(SnapshotCallback, self).__init__()
        self.snapshots = snapshots

    def on_epoch_end(self, epoch, logs=None):
        if epoch in [9, 19, 29, 39, 49]:  # Snapshots aux 10e, 20e, 30e, 40e, 50e époques
            snapshot = self.model.get_weights()
            self.snapshots.append(snapshot)

snapshots = []
cosine_annealing_schedule = LearningRateScheduler(cosine_annealing)
snapshot_callback = SnapshotCallback(snapshots)

# %% [markdown]
# **Étape 6: Compilation et entraînement du modèle**
#
# Le modèle est compilé et entraîné avec la stratégie Snapshot Ensemble.

# %%
model = create_model()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(ds_train,
                    validation_data=ds_test,
                    epochs=50,
                    callbacks=[cosine_annealing_schedule, snapshot_callback])

# %% [markdown]
# **Étape 7: Création d'ensembles avec les Snapshots**
#
# On combine les snapshots pour créer différents ensembles de modèles et les évaluer.

# %%
def ensemble_predictions(models, input_data):
    predictions = [model.predict(input_data) for model in models]
    return tf.reduce_mean(predictions, axis=0)

# Créer des modèles pour chaque snapshot
snapshot_models = [create_model() for _ in snapshots]

# Charger les poids des snapshots
for i, snapshot in enumerate(snapshots):
    snapshot_models[i].set_weights(snapshot)

# Combinaisons des ensembles de snapshots
ensemble_pred_1 = ensemble_predictions(snapshot_models[:5], ds_test)  # Snapshots [1, 2, 3, 4, 5]
ensemble_pred_2 = ensemble_predictions(snapshot_models[1:], ds_test)  # Snapshots [2, 3, 4, 5]
ensemble_pred_3 = ensemble_predictions(snapshot_models[2:], ds_test)  # Snapshots [3, 4, 5]
ensemble_pred_4 = ensemble_predictions(snapshot_models[2:4], ds_test)  # Snapshots [3, 4]
ensemble_pred_5 = ensemble_predictions(snapshot_models[3:5], ds_test)  # Snapshots [4, 5]

# %% [markdown]
# **Étape 8: Évaluation des ensembles**
#
# On évalue les performances de chaque ensemble en termes d'exactitude.

# %%
def evaluate_ensemble(ensemble_predictions, ds_test):
    y_true = []
    y_pred = []
    for images, labels in ds_test:
        y_true.extend(labels.numpy())
        y_pred.extend(tf.round(ensemble_predictions(images)).numpy())

    accuracy = np.mean(np.array(y_true) == np.array(y_pred))
    return accuracy

# Calculer l'exactitude pour chaque ensemble
accuracy_ensemble_1 = evaluate_ensemble(ensemble_pred_1, ds_test)
accuracy_ensemble_2 = evaluate_ensemble(ensemble_pred_2, ds_test)
accuracy_ensemble_3 = evaluate_ensemble(ensemble_pred_3, ds_test)
accuracy_ensemble_4 = evaluate_ensemble(ensemble_pred_4, ds_test)
accuracy_ensemble_5 = evaluate_ensemble(ensemble_pred_5, ds_test)

print(f"Exactitude Ensemble 1 (1,2,3,4,5): {accuracy_ensemble_1}")
print(f"Exactitude Ensemble 2 (2,3,4,5): {accuracy_ensemble_2}")
print(f"Exactitude Ensemble 3 (3,4,5): {accuracy_ensemble_3}")
print(f"Exactitude Ensemble 4 (3,4): {accuracy_ensemble_4}")
print(f"Exactitude Ensemble 5 (4,5): {accuracy_ensemble_5}")

# %% [markdown]
# **Étape 9: Visualisation avec GradCAM**
#
# Utilisez GradCAM pour visualiser les zones activées par le modèle lors de la prédiction.

# %%
import cv2

def get_gradcam_heatmap(model, image, last_conv_layer_name):
    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(last_conv_layer_name).output, model.output])

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(image)
        loss = predictions[:, 0]

    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    heatmap = tf.reduce_mean(tf.multiply(pooled_grads, conv_outputs), axis=-1)
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
    heatmap = tf.squeeze(heatmap).numpy()

    return heatmap

# Appliquer GradCAM sur une image de test
last_conv_layer_name = 'top_conv'
image = next(iter(ds_test.take(1)))[0]

heatmap = get_gradcam_heatmap(model, image, last_conv_layer_name)

# Superposer la heatmap sur l'image originale
image = image.numpy().squeeze()
heatmap = cv2.resize(heatmap, (image.shape[1], image.shape[0]))
heatmap = np.uint8(255 * heatmap)

plt.imshow(image)
plt.imshow(heatmap, cmap='jet', alpha=0.4)
plt.show()

# %% [markdown]
# **Étape 10: Sauvegarder chaque modèle Snapshot**
#
# Après avoir créé les différents modèles de snapshots et évalué leurs performances, vous pouvez les sauvegarder pour une future utilisation.

# %%
# Sauvegarder chaque snapshot au format .h5
for i, snapshot_model in enumerate(snapshot_models):
    h5_target_path = f'datas/snapshot_model_{i+1}.h5'
    snapshot_model.save(h5_target_path)
    print(f'Modèle snapshot {i+1} sauvegardé au format .h5 dans {h5_target_path}')
